# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv("C:/Users/pc/Downloads/covid_data_kerala.csv")
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[: , -1].values

# %%
dataset.head()
# Out:
#          Date  Confirmed  Recovered  Deceased
# 0  31-01-2020          0          0         0
# 1  01-02-2020          0          0         0
# 2  02-02-2020          1          0         0
# 3  03-02-2020          1          0         0
# 4  04-02-2020          0          0         0

# %%
dataset.columns
# Out:
# Index(['Date', 'Confirmed', 'Recovered', 'Deceased'], dtype='object')

# %%
dataset.tail()
# Out:
#            Date  Confirmed  Recovered  Deceased
# 836  16-05-2022        324        364        31
# 837  17-05-2022        596        366         6
# 838  18-05-2022        501        460        17
# 839  19-05-2022        556        362        23
# 840  20-05-2022        558        446        63

# %%
dataset.describe()
# Out:
#           Confirmed     Recovered     Deceased
# count    841.000000    841.000000   841.000000
# mean    7788.395957   7702.123662    82.656361
# std    10295.657109  10421.811291   126.911451
# min        0.000000      0.000000     0.000000
# 25%      438.000000    362.000000     8.000000
# 50%     4470.000000   4337.000000    25.000000
# 75%     9445.000000   9972.000000   122.000000
# max    55475.000000  99651.000000  1205.000000

# %%
dataset.isnull().sum()
# Out:
# Date         0
# Confirmed    0
# Recovered    0
# Deceased     0
# dtype: int64

# %%
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer( transformers =[('encoder', OneHotEncoder(),[])],remainder='passthrough')

x = np.array(ct.fit_transform(x))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[118.18 114.  ]
#  [ 30.62   0.  ]
#  [ 69.84 136.  ]
#  [ 48.81  12.  ]
#  [ 64.92 177.  ]
#  [ 50.5   15.  ]
#  [ 84.84  26.  ]
#  [211.84 198.  ]
#  [297.88 595.  ]
#  [ 68.71 370.  ]
#  [ 33.07  74.  ]
#  [ 58.02 245.  ]
#  [ 68.    22.  ]
#  [ 63.25 315.  ]
#  [ 63.42  27.  ]
#  [ 68.28  26.  ]
#  [ 30.05   0.  ]
#  [ 80.41  22.  ]
#  [ 98.22 146.  ]
#  [103.06 363.  ]
#  [ 43.37   4.  ]
#  [ 43.75  15.  ]
#  [118.71  88.  ]
#  [228.67 146.  ]
#  [ 30.05   0.  ]
#  [ 50.   166.  ]
#  [ 98.7  130.  ]
#  [105.17  57.  ]
#  [ 44.04   7.  ]
#  [ 75.13  24.  ]
#  [131.63 147.  ]
#  [171.38 319.  ]
#  [ 30.17   0.  ]
#  [193.58 208.  ]
#  [ 77.18 358.  ]
#  [ 73.38 210.  ]
#  [ 30.49   1.  ]
#  [182.72 132.  ]
#  [ 49.02 124.  ]
#  [ 30.05   0.  ]
#  [115.87 115.  ]
#  [ 30.05   0.  ]
#  [264.15 140.  ]
#  [ 85.05 362.  ]
#  [ 76.87  23.  ]
#  [ 51.46  11.  ]
#  [ 53.08  21.  ]
#  [ 31.61  36.  ]
#  [ 30.05   0.  ]
#  [ 30.93   0.  ]
#  [176.42 132.  ]
#  [118.82 151.  ]
#  [226.88 181.  ]
#  [ 39.88  15.  ]
#  [ 54.47  21.  ]
#  [ 58.52 225.  ]
#  [ 68.4  158.  ]
#  [248.63  79.  ]
#  [ 64.27  25.  ]
#  [130.14 173.  ]
#  [ 53.55 218.  ]
#  [298.   492.  ]
#  [159.54 116.  ]
#  [148.27 142.  ]
#  [ 61.81 243.  ]
#  [ 47.24  78.  ]
#  [ 30.68   0.  ]
#  [ 30.11   0.  ]
#  [ 39.    15.  ]
#  [ 38.74  10.  ]
#  [ 52.64  20.  ]
#  [ 31.17   2.  ]
#  [ 44.27  12.  ]
#  [120.36  95.  ]
#  [318.66 176.  ]
#  [ 56.83 320.  ]
#  [ 67.78  28.  ]
#  [ 30.1    0.  ]
#  [ 38.44   9.  ]
#  [ 30.88   0.  ]
#  [ 67.37  25.  ]
#  [ 91.68 563.  ]
#  [ 67.08 708.  ]
#  [144.92 165.  ]
#  [254.66 475.  ]
#  [ 32.57   6.  ]
#  [ 42.28 111.  ]
#  [ 81.95  23.  ]
#  [ 62.93 110.  ]
#  [252.47  89.  ]
#  [166.93 227.  ]
#  [ 30.05   0.  ]
#  [ 32.09   1.  ]
#  [ 77.99  24.  ]
#  [ 76.7   65.  ]
#  [293.   142.  ]
#  [ 80.89  27.  ]
#  [146.12 194.  ]
#  [ 58.48  24.  ]
#  [ 59.37 161.  ]
#  [ 73.43  25.  ]
#  [ 30.06   0.  ]
#  [ 67.93  16.  ]
#  [229.17 171.  ]
#  [ 30.07   0.  ]
#  [ 30.13   0.  ]
#  [ 48.01  16.  ]
#  [ 32.54  21.  ]
#  [ 70.95  21.  ]
#  [229.15 304.  ]
#  [ 30.05   0.  ]
#  [100.06 124.  ]
#  [ 43.05  16.  ]
#  [ 71.46  26.  ]
#  [ 39.4    5.  ]
#  [ 42.95  17.  ]
#  [ 53.54  25.  ]
#  [ 30.46   0.  ]
#  [ 51.33  14.  ]
#  [ 30.1    0.  ]
#  [ 68.32  21.  ]
#  [ 30.09   0.  ]
#  [ 30.69   0.  ]
#  [142.24  41.  ]
#  [ 64.02  28.  ]
#  [ 60.78  15.  ]
#  [ 75.8  482.  ]
#  [ 30.05   0.  ]
#  [ 66.83  19.  ]
#  [ 71.81  28.  ]
#  [ 71.83  19.  ]
#  [ 67.86  27.  ]
#  [148.3   56.  ]
#  [164.1  152.  ]
#  [ 41.41  12.  ]
#  [ 39.21   6.  ]
#  [ 30.59   1.  ]
#  [ 77.47  29.  ]
#  [169.   215.  ]
#  [ 63.49  24.  ]
#  [ 57.7   16.  ]
#  [ 83.47  25.  ]
#  [ 67.37  21.  ]
#  [133.58  84.  ]
#  [ 30.07   0.  ]
#  [ 36.35   4.  ]
#  [ 33.01   8.  ]
#  [ 30.1    0.  ]
#  [ 30.05   0.  ]
#  [ 32.19  64.  ]
#  [ 74.42  26.  ]
#  [137.18 149.  ]
#  [ 30.13   0.  ]
#  [ 32.27  63.  ]
#  [ 59.54  23.  ]
#  [ 32.42  31.  ]
#  [ 30.19   0.  ]
#  [134.98 161.  ]
#  [ 78.96 201.  ]
#  [ 30.05   0.  ]
#  [177.95  48.  ]
#  [ 30.13   0.  ]
#  [ 65.6   23.  ]
#  [215.39 186.  ]
#  [ 66.65 159.  ]
#  [155.51 105.  ]
#  [109.44 106.  ]
#  [ 75.31 467.  ]
#  [ 31.79  19.  ]]

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred,color='blue',alpha=0.7)
plt.xlabel("active cases")
plt.ylabel("deaths")
plt.title("active cases vs deaths")

plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)],color='red',alpha=0.7,linestyle='--')
plt.show()
